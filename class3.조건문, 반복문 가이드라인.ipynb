# %% [markdown]
# ## if문이 필요한 이유
# 주어진 조건을 판단한 후 그 상황에 맞게 처리해야 할 경우가 생긴다.
#
# 프로그래밍에서 조건을 판단하여 해당 조건에 맞는 상황을 수행하는 데 쓰는 것이 바로 if 문이다.

# %%
score = int(input('점수를 입력하시오'))

if score >= 60: #60점 이상이면 합격, 60점 미만이면 불합격
    print(str(score) + '점, 합격입니다')
else:    #score가 60점 미만이면 else문이 실행되어 불합격 출력
    print(str(score) + '점, 불합격입니다')
# Out:
# -5점, 불합격입니다

# %% [markdown]
# * if 문을 만들 때는 if 조건문: 바로 다음 문장부터 if 문에 속하는 모든 문장에 들여쓰기(indentation)를 해야 한다.

# %%
math = int (input('수학 점수를 입력하시오'))
eng = int (input('영어 점수를 입력하시오'))

if math>=60 and eng >=60:
    print(str (math) + '점, ' + str(eng) + '점, 합격입니다')
else:
    print(str (math) + '점, ' + str(eng) + '점, 불합격입니다')
# Out:
# 55점, 60점, 불합격입니다

# %% [markdown]
# if 조건문에서 '조건문'이란 참과 거짓을 판단하는 문장을 말한다.
# - 비교연산자	설명
# - x < y	x가 y보다 작다.
# - x > y	x가 y보다 크다.
# - x == y	x와 y가 같다.
# - x != y	x와 y가 같지 않다.
# - x >= y	x가 y보다 크거나 같다.
# - x <= y	x가 y보다 작거나 같다.

# %%
list1 = [1, 2, 3, 4, 5]
tuple1 = (2, 3, 4, 5)

print(1  in list1)
print(1 in tuple1)
print(1 not in list1)
print(1 not in tuple1)
# Out:
# True
# False
# False
# True

# %% [markdown]
# and, or, not
# - 조건을 판단하기 위해 사용하는 다른 연산자로는 and, or, not이 있다.
# - x or y	x와 y 둘 중 하나만 참이어도 참이다.
# - x and y	x와 y 모두 참이어야 참이다.
# - not x	x가 거짓이면 참이다.

# %%
pocket = ['phone', 'money', 'wallet', 'IDcard']

if 'money' in pocket:
    print('택시를 타세요')
else: print('걸어가세요')

if 'money' not in pocket:
    print('걸어가세요')
else: print('택시를 타세요')
# Out:
# 택시를 타세요
# 택시를 타세요

# %% [markdown]
# ### in, not in
# - 파이썬은 다른 프로그래밍 언어에서 쉽게 볼 수 없는 재미있는 조건문도 제공한다.
#
# - in	not in
# - x in 리스트	x not in 리스트
# - x in 튜플	x not in 튜플
# - x in 문자열	x not in 문자열

# %% [markdown]
# ### 다양한 조건을 판단하는 elif
# - 주머니에 돈이 있으면 택시를 타고 가고, 주머니에 돈은 없지만 카드가 있으면 택시를 타고 가고, 돈도 없고 카드도 없으면 걸어가라.
# - 위 문장을 보면 조건을 판단하는 부분이 두 군데 있다.
# - 먼저 주머니에 돈이 있는지를 판단해야 하고, 주머니에 돈이 없으면 다시 카드가 있는지 판단해야 한다.
# - 파이썬에서는 다중 조건 판단을 가능하게 하는 elif를 사용한다.

# %%
pocket = ['phone', 'money', 'wallet', 'IDcard']
if 'money' in pocket and 'card' in pocket:
    print('아무거나 타세요')
elif 'money' in pocket:
    print('버스를 타세요')
elif 'card' in pocket:
    print('택시를 타세요')
else:
    print('아무것도 없네요. 걸어가세요')
# Out:
# 버스를 타세요

# %%
a = int(input("a의 값을 입력하세요:"))
b = int(input("b의 값을 입력하세요:"))
if (a > b):
    print(str(a) +', a는 b보다 큽니다')
elif (a < b):
    print(str(b)+', b는 a보다 큽니다')
else:
    print('a는 b와 같습니다')
# Out:
# 5, b는 a보다 큽니다

# %% [markdown]
# # 조건부 표현식
# - 조건에 따라 변수에 서로 다른 값을 대입하고 싶을 때가 있다.
# - 예를 들어 점수를 통하여 등급을 나누는 식을 만들어 본다.
# - "조건이 참이면 '참일_때_값'을, 거짓이면 '거짓일_때_값'을 변수에 대입한다"는 의미이다.

# %%
score = int(input('점수를 입력하시오'))
if score >= 90:
    print(str(score) + '점, A등급입니다.')
elif score >= 80:
    print(str(score) + '점, B등급입니다.')
elif score >= 70:
    print(str(score) + '점, C등급입니다.')
elif score < 70:
    print(str(score) + '점, D등급입니다.')
# Out:
# 65점, D등급입니다.

# %% [markdown]
# # while 문의 기본 구조
# - 다음은 while 문의 기본 구조이다.
# - while 문의 조건문은 num < 5이다.
# - 즉, num가 5보다 작은 동안 while 문에 포함된 문장들을 계속 수행한다.

# %%
# while 조건문:
#    수행할_문장1
#    수행할_문장2
#    수행할_문장3
num = 1

while num <= 5:
    print(num)
    num = num + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # while 문 강제로 빠져나가기
# - while 문은 조건문이 참인 동안 while 문 안의 내용을 반복적으로 수행한다.
# - 하지만 강제로 while 문을 빠져나가고 싶을 때가 있다.
# - 강제로 멈추게 하는 것이 바로 break 문이다.

# %%
num = 1
while True:
    print(num)
    num += 1
    if num > 5:
        break
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # while 문의 맨 처음으로 돌아가기
# - while 문 안의 문장을 수행할 때 입력 조건을 검사해서 조건에 맞지 않으면 while 문을 빠져나간다.
# - 그런데 프로그래밍을 하다 보면 while 문을 빠져나가지 않고,
# - while 문의 맨 처음(조건문)으로 다시 돌아가게 만들고 싶은 경우가 있다. 이때 사용하는 것이 바로 continue 문이다.

# %%
num = 0
while num <= 10:
    
    num += 1
    
    if num <5:
        continue
    print(num)
# Out:
# 5
# 6
# 7
# 8
# 9
# 10
# 11

# %%
num = int(input('정수를 입력하시오'))

i = 1
while i <= num:
    print(i**2)
    i = i+1 #연산을 이용하여 i의 값을 1씩 증가시키는 방법
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %% [markdown]
# # for 문의 기본 구조
# - for 문의 기본 구조는 다음과 같다.
# - ['one', 'two', 'three'] 리스트의 첫 번째 요소인 'one'이 먼저 i 변수에 대입된 후 print(i) 문장을 수행한다.
# - 다음에 두 번째 요소 'two'가 i 변수에 대입된 후 print(i) 문장을 수행하고, 리스트의 마지막 요소까지 이것을 반복한다.

# %%
#for 변수 in 리스트(또는 튜플, 문자열):
#    수행할_문장1
#    수행할_문장2

list1 = ['one', 'two', 'three', 'four', 'five']

for i in list1:
    print(i*2)
# Out:
# oneone
# twotwo
# threethree
# fourfour
# fivefive

# %%
for i in range(0, 10, 3): # 더하기
    print(i)

for i in range(-10, -20, -2): # 빼기
    print(i)
# Out:
# 0
# 3
# 6
# 9
# -10
# -12
# -14
# -16
# -18

# %% [markdown]
# # for 문의 응용
# - 총 5명의 학생이 시험을 보았는데 시험 점수가 50점 이상이면 합격이고 그렇지 않으면 불합격이다.
# - 합격인지, 불합격인지 결과를 보여 주시오.

# %%
score = [50, 49, 60, 44, 5]
for s in score:
    if s >=50:
        print(str(s) + '점, 합격입니다.')
    else:
        print(str(s) + '점, 불합격입니다.')
# Out:
# 50점, 합격입니다.
# 49점, 불합격입니다.
# 60점, 합격입니다.
# 44점, 불합격입니다.
# 5점, 불합격입니다.
